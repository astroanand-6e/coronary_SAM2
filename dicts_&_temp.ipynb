# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
my_dict = {
    'key1': [1, 2, 3],
    'key2': [4, 5, 6],
    'key3': [7, 8, 9]
}

for key, values in my_dict.items():
    values_1 = values[0]
    values_2 = values[1]
    values_3 = values[2]
    print(f'{key} has values {values_1}, {values_2}, {values_3}')
# Out:
# key1 has values 1, 2, 3
# key2 has values 4, 5, 6
# key3 has values 7, 8, 9

# %%
img_path = "/Users/anand/Github_project_portfolio/SAM2_CASBloDaM/Aug_dataset_cor_arteries/Augmented_mask/1_aug1.png"
img = plt.imread(img_path)
plt.imshow(img, cmap='gray')

# %%
### Inverting the image Trial 
## white = 255, black = 0
# soo 255 - white(255) -> black & 255 - black(0) -> white


mask_try = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
invert = 255 - mask_try 

plt.imshow(invert, cmap='gray')

# %%
mask_path = "/Users/anand/Github_project_portfolio/SAM2_CASBloDaM/Aug_dataset_cor_arteries/Augmented_mask/1_aug1.png"
mask_1  = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
plt.imshow(255-mask_1, cmap='gray')

# %%
aug_img = "/Users/anand/Github_project_portfolio/SAM2_CASBloDaM/Aug_dataset_cor_arteries/Augmented_image/1_aug1.png"

aug_img = cv2.imread(aug_img, cv2.IMREAD_GRAYSCALE)


norm_aug = cv2.GaussianBlur(aug_img, (5,5),1.5)



plt.figure(figsize=(20, 20))
plt.subplot(1, 2, 1)
plt.title('Augmented Image')
plt.axis('off')
plt.imshow(aug_img, cmap='gray')

plt.subplot(1, 2, 2)
plt.title('Normalized Augmented Image')
plt.axis('off')
plt.imshow(norm_aug, cmap='gray')

print(aug_img.shape)
# Out:
# (1024, 1024)

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
aug_img = "/Users/anand/Github_project_portfolio/SAM2_CASBloDaM/Aug_dataset_cor_arteries/Augmented_mask/1_aug3.png" 
img = cv.imread(aug_img, cv.IMREAD_GRAYSCALE)
assert img is not None, "file could not be read, check with os.path.exists()"
edges = cv.Canny(img,100,200)
 
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
 
plt.show()

# %%
contour = cv2.findContours(img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
plt.imshow(contour, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 2
#       1 contour = cv2.findContours(img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
# ----> 2 plt.imshow(contour, cmap='gray')
#
# File ~/miniconda3/envs/sam2/lib/python3.10/site-packages/matplotlib/pyplot.py:3592, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3570 @_copy_docstring_and_deprecators(Axes.imshow)
#    3571 def imshow(
#    3572     X: ArrayLike | PIL.Image.Image,
#    (...)
#    3590     **kwargs,
#    3591 ) -> AxesImage:
# -> 3592     __ret = gca().imshow(
#    3593         X,
#    3594         cmap=cmap,
#    3595         norm=norm,
#    3596         aspect=aspect,
#    3597         interpolation=interpolation,
#    3598         alpha=alpha,
# ...
